# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import random
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential, save_model
from tensorflow.keras.layers import Input, Conv2D, Lambda, Reshape, AveragePooling2D, Dense, ReLU, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from os import listdir
from matplotlib import image
from keras import regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from tensorflow.keras import layers
from tensorflow.keras import backend as K
from keras.layers import Layer
from keras import activations
from keras import utils
import joblib
import math
from multiprocessing import Pool
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix
# !pip install visualkeras
import visualkeras
from tensorflow.keras.preprocessing import image
# %matplotlib inline
from sklearn.model_selection import KFold
from keras import initializers
from google.colab import drive
from tensorflow.keras.models import load_model
import seaborn as sns
from PIL import Image
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.0/993.0 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.16 visualkeras-0.0.2

# %%
# Check if the TPU system has already been initialized
if 'COLAB_TPU_ADDR' in os.environ:
    resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])
    tf.config.experimental_connect_to_cluster(resolver)
    tf.tpu.experimental.initialize_tpu_system(resolver)
    strategy = tf.distribute.TPUStrategy(resolver)
else:
    strategy = tf.distribute.OneDeviceStrategy('GPU:0')  # Use GPU if TPU is not available

# %%
data_dir = '/content/drive/MyDrive/Colab Notebooks/Projects/Final(Undergraduate)/[augmented]RIMONE-DL_dataset'

# %%
with strategy.scope():
    batch_size = 48
    Image_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
    )

# %%
from collections import Counter

with strategy.scope():
    generator = ImageDataGenerator(rescale=1./255)
    train_generator = generator.flow_from_directory(
          data_dir,
          target_size=(256, 256),
          batch_size=batch_size,
          class_mode='categorical'
    )

    num_batches = len(train_generator)
    print('Number of batches: ', num_batches)

    images_per_batch = train_generator.batch_size
    print('Images per batch: ', images_per_batch)

    num_classes = train_generator.num_classes
    print("Number of classes: ", num_classes)

    # Count the number of images in each class
    class_indices = train_generator.classes
    image_counts_per_class = dict(Counter(class_indices))

    print("**Number of images per class**")
    total_images = 0
    for class_index in range(num_classes):
        class_name = list(train_generator.class_indices.keys())[list(train_generator.class_indices.values()).index(class_index)]
        class_count = image_counts_per_class[class_index]
        total_images += class_count
        print(f"Class '{class_name}': {class_count} images")

    print('Total number of images:', total_images)

    # Plot the distribution of images per class
    plt.bar(image_counts_per_class.keys(), image_counts_per_class.values())
    plt.xticks(range(num_classes), [list(train_generator.class_indices.keys())[i] for i in range(num_classes)], rotation=45)
    plt.xlabel('Class')
    plt.ylabel('Number of Images')
    plt.title('Distribution of Images per Class')
    plt.show()
# Out:
# Found 618 images belonging to 2 classes.
# Number of batches:  13
# Images per batch:  48
# Number of classes:  2
# **Number of images per class**
# Class 'Glaucoma': 309 images
# Class 'Normal': 309 images
# Total number of images: 618

# %%
from sklearn.model_selection import train_test_split

with strategy.scope():
  # Initialize empty lists to store data splits
  X_train, y_train, X_val, y_val, X_test, y_test = [], [], [], [], [], []

  # Loop through batches from the generator
  for _ in range(num_batches):
      X_batch, y_batch = train_generator.next()

      # Split each batch into train, validation, and test
      X_batch_train, X_batch_temp, y_batch_train, y_batch_temp = train_test_split(X_batch, y_batch, test_size=0.4, random_state=42)
      X_batch_val, X_batch_test, y_batch_val, y_batch_test = train_test_split(X_batch_temp, y_batch_temp, test_size=0.5, random_state=42)

      # Append the splits to the lists
      X_train.append(X_batch_train)
      y_train.append(y_batch_train)
      X_val.append(X_batch_val)
      y_val.append(y_batch_val)
      X_test.append(X_batch_test)
      y_test.append(y_batch_test)

  # Concatenate the splits to get the final train, validation, and test sets
  X_train = np.concatenate(X_train)
  y_train = np.concatenate(y_train)
  X_val = np.concatenate(X_val)
  y_val = np.concatenate(y_val)
  X_test = np.concatenate(X_test)
  y_test = np.concatenate(y_test)

# %% [markdown]
# CNN

# %%
def create_cnn_model(input_shape):
    model = Sequential()
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu', name = 'Block1_Conv1', input_shape=input_shape))
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu', name = 'Block1_Conv2'))
    model.add(MaxPooling2D(pool_size=(2, 2), name = 'Block1_Pool'))
    #model.add(Dropout(0.25, name = 'Block1_Dropout'))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu', name = 'Block2_Conv1'))
    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu', name = 'Block2_Conv2'))
    model.add(MaxPooling2D(pool_size=(2, 2), name = 'Block2_Pool'))
    #model.add(Dropout(0.25, name = 'Block2_Dropout'))

    model.add(Conv2D(filters=256, kernel_size=(3, 3), activation='relu', name = 'Block3_Conv1'))
    model.add(Conv2D(filters=256, kernel_size=(3, 3), activation='relu', name = 'Block3_Conv2'))
    model.add(MaxPooling2D(pool_size=(2, 2), name = 'Block3_Pool'))
    #model.add(Dropout(0.25, name = 'Block3_Dropout'))

    model.add(Conv2D(filters=256, kernel_size=(3, 3), activation='relu', name = 'Block4_Conv1'))
    model.add(MaxPooling2D(pool_size=(2, 2), name = 'Block4_Pool'))
    model.add(Dropout(0.25, name = 'Block4_Dropout'))

    model.add(Flatten(name = 'Flatten'))
    model.add(Dropout(0.5, name = 'Dropout'))
    model.add(Dense(units=num_classes, activation='sigmoid', name = 'Output'))
    return model

# %%
with strategy.scope():
  # Defines the input shape
  input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
  cnn_model = create_cnn_model(input_shape)

# %%
with strategy.scope():
  # Compile the model
  cnn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics='accuracy')

  # Model summary
  cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Block1_Conv1 (Conv2D)       (None, 254, 254, 64)      1792
#
#  Block1_Conv2 (Conv2D)       (None, 252, 252, 64)      36928
#
#  Block1_Pool (MaxPooling2D)  (None, 126, 126, 64)      0
#
#  Block2_Conv1 (Conv2D)       (None, 124, 124, 128)     73856
#
#  Block2_Conv2 (Conv2D)       (None, 122, 122, 128)     147584
#
#  Block2_Pool (MaxPooling2D)  (None, 61, 61, 128)       0
#
#  Block3_Conv1 (Conv2D)       (None, 59, 59, 256)       295168
#
#  Block3_Conv2 (Conv2D)       (None, 57, 57, 256)       590080
#
#  Block3_Pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  Block4_Conv1 (Conv2D)       (None, 26, 26, 256)       590080
#
#  Block4_Pool (MaxPooling2D)  (None, 13, 13, 256)       0
#
#  Block4_Dropout (Dropout)    (None, 13, 13, 256)       0
#
#  Flatten (Flatten)           (None, 43264)             0
#
#  Dropout (Dropout)           (None, 43264)             0
#
#  Output (Dense)              (None, 2)                 86530
#
# =================================================================
# Total params: 1,822,018
# Trainable params: 1,822,018
# Non-trainable params: 0
# _________________________________________________________________

# %%
with strategy.scope():
  vis = visualkeras.layered_view(cnn_model, scale_xy=1, scale_z=1, max_z=100, legend = True)
  vis.show()

# %%
with strategy.scope():
  # Define the directory to save the model checkpoints
  checkpoint_dir = '/content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection'

  # Ensure the directory exists
  os.makedirs(checkpoint_dir, exist_ok=True)

  epochs = 50

# %%
class ValidationAccuracyStopCallback(Callback):
    def __init__(self, target_accuracy):
        super(ValidationAccuracyStopCallback, self).__init__()
        self.target_accuracy = target_accuracy

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('val_accuracy') >= self.target_accuracy:
            print(f"Stopping training as val_accuracy reached {self.target_accuracy}%.")
            self.model.stop_training = True

# %%
class AccuracyStopCallback(Callback):
    def __init__(self, target_accuracy):
        super(AccuracyStopCallback, self).__init__()
        self.target_accuracy = target_accuracy

    def on_epoch_end(self, epoch, logs=None):
        if logs.get('accuracy') >= self.target_accuracy:
            print(f"Stopping training as accuracy reached {self.target_accuracy}%.")
            self.model.stop_training = True

# %%
with strategy.scope():
  # Define the custom validation accuracy stopping callback
    target_accuracy = 1.0
    val_accuracy_stop = ValidationAccuracyStopCallback(target_accuracy)

# %%
with strategy.scope():
  # Define the custom validation accuracy stopping callback
    target_accuracy = 1.0
    accuracy_stop = AccuracyStopCallback(target_accuracy)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

with strategy.scope():
  # Define the EarlyStopping callback
  early_stop = EarlyStopping(monitor='accuracy', patience=10, verbose=1, mode='max')

  # Create ModelCheckpoint callback for CNN model
  cnn_checkpoint_path = os.path.join(checkpoint_dir, 'cnn_model_checkpoint.h5')
  cnn_model_checkpoint = ModelCheckpoint(cnn_checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

  # Train the model on the training set
  CNN_history = cnn_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val), callbacks=[early_stop, val_accuracy_stop, accuracy_stop, cnn_model_checkpoint])#
# Out:
# Epoch 1/50
# 6/8 [=====================>........] - ETA: 0s - loss: 0.6953 - accuracy: 0.4722
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0043s vs `on_train_batch_end` time: 1.0742s). Check your callbacks.
# 8/8 [==============================] - ETA: 0s - loss: 0.6947 - accuracy: 0.4903
# Epoch 1: val_accuracy improved from -inf to 0.45312, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/cnn_model_checkpoint.h5
# 8/8 [==============================] - 27s 2s/step - loss: 0.6947 - accuracy: 0.4903 - val_loss: 0.6907 - val_accuracy: 0.4531
# Epoch 2/50
# 8/8 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.6150
# Epoch 2: val_accuracy improved from 0.45312 to 0.51562, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/cnn_model_checkpoint.h5
# 8/8 [==============================] - 2s 249ms/step - loss: 0.6931 - accuracy: 0.6150 - val_loss: 0.6754 - val_accuracy: 0.5156
# Epoch 3/50
# 8/8 [==============================] - ETA: 0s - loss: 0.6248 - accuracy: 0.6482
# Epoch 3: val_accuracy improved from 0.51562 to 0.84375, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/cnn_model_checkpoint.h5
# 8/8 [==============================] - 2s 275ms/step - loss: 0.6248 - accuracy: 0.6482 - val_loss: 0.4151 - val_accuracy: 0.8438
# Epoch 4/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.5120 - accuracy: 0.7589
# Epoch 4: val_accuracy did not improve from 0.84375
# 8/8 [==============================] - 2s 267ms/step - loss: 0.5183 - accuracy: 0.7535 - val_loss: 0.5748 - val_accuracy: 0.6953
# Epoch 5/50
# 8/8 [==============================] - ETA: 0s - loss: 0.5221 - accuracy: 0.7839
# Epoch 5: val_accuracy did not improve from 0.84375
# 8/8 [==============================] - 1s 180ms/step - loss: 0.5221 - accuracy: 0.7839 - val_loss: 0.3876 - val_accuracy: 0.7969
# Epoch 6/50
# 8/8 [==============================] - ETA: 0s - loss: 0.4533 - accuracy: 0.8061
# Epoch 6: val_accuracy did not improve from 0.84375
# 8/8 [==============================] - 1s 182ms/step - loss: 0.4533 - accuracy: 0.8061 - val_loss: 0.4100 - val_accuracy: 0.8125
# Epoch 7/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4662 - accuracy: 0.7857
# Epoch 7: val_accuracy improved from 0.84375 to 0.86719, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/cnn_model_checkpoint.h5
# 8/8 [==============================] - 2s 243ms/step - loss: 0.4590 - accuracy: 0.7839 - val_loss: 0.3255 - val_accuracy: 0.8672
# Epoch 8/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4232 - accuracy: 0.7976
# Epoch 8: val_accuracy improved from 0.86719 to 0.90625, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/cnn_model_checkpoint.h5
# 8/8 [==============================] - 2s 231ms/step - loss: 0.4186 - accuracy: 0.8006 - val_loss: 0.3202 - val_accuracy: 0.9062
# Epoch 9/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3866 - accuracy: 0.8244
# Epoch 9: val_accuracy did not improve from 0.90625
# 8/8 [==============================] - 1s 180ms/step - loss: 0.3752 - accuracy: 0.8338 - val_loss: 0.4207 - val_accuracy: 0.8281
# Epoch 10/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4945 - accuracy: 0.8036
# Epoch 10: val_accuracy did not improve from 0.90625
# 8/8 [==============================] - 1s 176ms/step - loss: 0.4960 - accuracy: 0.7978 - val_loss: 0.5194 - val_accuracy: 0.7500
# Epoch 11/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.5353 - accuracy: 0.7321
# Epoch 11: val_accuracy did not improve from 0.90625
# 8/8 [==============================] - 2s 208ms/step - loss: 0.5314 - accuracy: 0.7313 - val_loss: 0.4462 - val_accuracy: 0.7812
# Epoch 12/50
# 8/8 [==============================] - ETA: 0s - loss: 0.4424 - accuracy: 0.8006
# Epoch 12: val_accuracy did not improve from 0.90625
# 8/8 [==============================] - 1s 204ms/step - loss: 0.4424 - accuracy: 0.8006 - val_loss: 0.3179 - val_accuracy: 0.8594
# Epoch 13/50
# 8/8 [==============================] - ETA: 0s - loss: 0.3610 - accuracy: 0.8560
# Epoch 13: val_accuracy did not improve from 0.90625
# 8/8 [==============================] - 2s 210ms/step - loss: 0.3610 - accuracy: 0.8560 - val_loss: 0.3068 - val_accuracy: 0.8594
# Epoch 14/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3586 - accuracy: 0.8690
# Epoch 14: val_accuracy did not improve from 0.90625
# 8/8 [==============================] - 1s 191ms/step - loss: 0.3602 - accuracy: 0.8698 - val_loss: 0.3330 - val_accuracy: 0.8750
# Epoch 15/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3158 - accuracy: 0.8839
# Epoch 15: val_accuracy did not improve from 0.90625
# 8/8 [==============================] - 1s 182ms/step - loss: 0.3124 - accuracy: 0.8892 - val_loss: 0.3223 - val_accuracy: 0.8672
# Epoch 16/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3291 - accuracy: 0.8601
# Epoch 16: val_accuracy did not improve from 0.90625
# 8/8 [==============================] - 1s 177ms/step - loss: 0.3331 - accuracy: 0.8560 - val_loss: 0.3207 - val_accuracy: 0.8750
# Epoch 17/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3034 - accuracy: 0.8869
# Epoch 17: val_accuracy did not improve from 0.90625
# 8/8 [==============================] - 1s 173ms/step - loss: 0.3081 - accuracy: 0.8837 - val_loss: 0.2409 - val_accuracy: 0.8906
# Epoch 18/50
# 8/8 [==============================] - ETA: 0s - loss: 0.3197 - accuracy: 0.8670
# Epoch 18: val_accuracy did not improve from 0.90625
# 8/8 [==============================] - 1s 183ms/step - loss: 0.3197 - accuracy: 0.8670 - val_loss: 0.2635 - val_accuracy: 0.8906
# Epoch 19/50
# 8/8 [==============================] - ETA: 0s - loss: 0.3170 - accuracy: 0.8726
# Epoch 19: val_accuracy did not improve from 0.90625
# 8/8 [==============================] - 1s 182ms/step - loss: 0.3170 - accuracy: 0.8726 - val_loss: 0.3555 - val_accuracy: 0.8438
# Epoch 20/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3170 - accuracy: 0.8750
# Epoch 20: val_accuracy did not improve from 0.90625
# 8/8 [==============================] - 1s 173ms/step - loss: 0.3216 - accuracy: 0.8670 - val_loss: 0.2227 - val_accuracy: 0.9062
# Epoch 21/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2680 - accuracy: 0.9018
# Epoch 21: val_accuracy improved from 0.90625 to 0.93750, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/cnn_model_checkpoint.h5
# 8/8 [==============================] - 2s 312ms/step - loss: 0.2786 - accuracy: 0.8947 - val_loss: 0.2044 - val_accuracy: 0.9375
# Epoch 22/50
# 8/8 [==============================] - ETA: 0s - loss: 0.3139 - accuracy: 0.8670
# Epoch 22: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 2s 211ms/step - loss: 0.3139 - accuracy: 0.8670 - val_loss: 0.3528 - val_accuracy: 0.8281
# Epoch 23/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3064 - accuracy: 0.8601
# Epoch 23: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 174ms/step - loss: 0.3043 - accuracy: 0.8643 - val_loss: 0.3312 - val_accuracy: 0.8594
# Epoch 24/50
# 8/8 [==============================] - ETA: 0s - loss: 0.3183 - accuracy: 0.8809
# Epoch 24: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 2s 261ms/step - loss: 0.3183 - accuracy: 0.8809 - val_loss: 0.3345 - val_accuracy: 0.8594
# Epoch 25/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2888 - accuracy: 0.8869
# Epoch 25: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 184ms/step - loss: 0.2799 - accuracy: 0.8864 - val_loss: 0.3550 - val_accuracy: 0.8594
# Epoch 26/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2518 - accuracy: 0.9077
# Epoch 26: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 186ms/step - loss: 0.2610 - accuracy: 0.9086 - val_loss: 0.3132 - val_accuracy: 0.8984
# Epoch 27/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2305 - accuracy: 0.9141
# Epoch 27: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 181ms/step - loss: 0.2305 - accuracy: 0.9141 - val_loss: 0.2528 - val_accuracy: 0.8984
# Epoch 28/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2215 - accuracy: 0.9280
# Epoch 28: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 2s 206ms/step - loss: 0.2215 - accuracy: 0.9280 - val_loss: 0.2141 - val_accuracy: 0.9062
# Epoch 29/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2055 - accuracy: 0.9197
# Epoch 29: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 176ms/step - loss: 0.2055 - accuracy: 0.9197 - val_loss: 0.2483 - val_accuracy: 0.9062
# Epoch 30/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9224
# Epoch 30: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 2s 207ms/step - loss: 0.1841 - accuracy: 0.9224 - val_loss: 0.3287 - val_accuracy: 0.8438
# Epoch 31/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2321 - accuracy: 0.9086
# Epoch 31: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 2s 207ms/step - loss: 0.2321 - accuracy: 0.9086 - val_loss: 0.2879 - val_accuracy: 0.8906
# Epoch 32/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2509 - accuracy: 0.9077
# Epoch 32: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 185ms/step - loss: 0.2454 - accuracy: 0.9114 - val_loss: 0.3573 - val_accuracy: 0.8438
# Epoch 33/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2291 - accuracy: 0.9018
# Epoch 33: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 180ms/step - loss: 0.2248 - accuracy: 0.9058 - val_loss: 0.2533 - val_accuracy: 0.8984
# Epoch 34/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2256 - accuracy: 0.9197
# Epoch 34: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 183ms/step - loss: 0.2256 - accuracy: 0.9197 - val_loss: 0.2467 - val_accuracy: 0.8984
# Epoch 35/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1775 - accuracy: 0.9375
# Epoch 35: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 181ms/step - loss: 0.1688 - accuracy: 0.9391 - val_loss: 0.2865 - val_accuracy: 0.9141
# Epoch 36/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1663 - accuracy: 0.9464
# Epoch 36: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 173ms/step - loss: 0.1568 - accuracy: 0.9501 - val_loss: 0.2549 - val_accuracy: 0.8906
# Epoch 37/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1245 - accuracy: 0.9554
# Epoch 37: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 176ms/step - loss: 0.1248 - accuracy: 0.9529 - val_loss: 0.2668 - val_accuracy: 0.8828
# Epoch 38/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1246 - accuracy: 0.9583
# Epoch 38: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 193ms/step - loss: 0.1242 - accuracy: 0.9584 - val_loss: 0.4135 - val_accuracy: 0.8594
# Epoch 39/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1018 - accuracy: 0.9554
# Epoch 39: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 185ms/step - loss: 0.0999 - accuracy: 0.9557 - val_loss: 0.3076 - val_accuracy: 0.9141
# Epoch 40/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9529
# Epoch 40: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 2s 205ms/step - loss: 0.1224 - accuracy: 0.9529 - val_loss: 0.2926 - val_accuracy: 0.8750
# Epoch 41/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1084 - accuracy: 0.9643
# Epoch 41: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 2s 215ms/step - loss: 0.1113 - accuracy: 0.9640 - val_loss: 0.2925 - val_accuracy: 0.8672
# Epoch 42/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.9086
# Epoch 42: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 191ms/step - loss: 0.2198 - accuracy: 0.9086 - val_loss: 0.3195 - val_accuracy: 0.8516
# Epoch 43/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9363
# Epoch 43: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 177ms/step - loss: 0.1842 - accuracy: 0.9363 - val_loss: 0.2802 - val_accuracy: 0.8828
# Epoch 44/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9446
# Epoch 44: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 179ms/step - loss: 0.1302 - accuracy: 0.9446 - val_loss: 0.3119 - val_accuracy: 0.8594
# Epoch 45/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1429 - accuracy: 0.9435
# Epoch 45: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 187ms/step - loss: 0.1427 - accuracy: 0.9418 - val_loss: 0.2997 - val_accuracy: 0.8672
# Epoch 46/50
# 8/8 [==============================] - ETA: 0s - loss: 0.0944 - accuracy: 0.9640
# Epoch 46: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 184ms/step - loss: 0.0944 - accuracy: 0.9640 - val_loss: 0.3078 - val_accuracy: 0.8672
# Epoch 47/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0870 - accuracy: 0.9554
# Epoch 47: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 179ms/step - loss: 0.0857 - accuracy: 0.9584 - val_loss: 0.3439 - val_accuracy: 0.8828
# Epoch 48/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0825 - accuracy: 0.9583
# Epoch 48: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 2s 256ms/step - loss: 0.0861 - accuracy: 0.9529 - val_loss: 0.3478 - val_accuracy: 0.8750
# Epoch 49/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0883 - accuracy: 0.9762
# Epoch 49: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 2s 204ms/step - loss: 0.0850 - accuracy: 0.9778 - val_loss: 0.3985 - val_accuracy: 0.8828
# Epoch 50/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1354 - accuracy: 0.9391
# Epoch 50: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 2s 213ms/step - loss: 0.1354 - accuracy: 0.9391 - val_loss: 0.3361 - val_accuracy: 0.8828

# %% [markdown]
# CAPSULE NETWORK

# %%
def squash(x, axis=-1, keepdims=True):
    squared_norm = tf.reduce_sum(tf.square(x), axis=axis, keepdims=keepdims)
    scale = squared_norm / (1 + squared_norm) / tf.sqrt(squared_norm + tf.keras.backend.epsilon())
    return scale * x

# %%
def margin_loss(y_true, y_pred):
    margin = 0.5
    margin_positive = K.square(K.relu(1 - margin - y_pred))
    loss = K.sum(y_true * margin_positive, axis=-1)
    return loss

# %%
class Class_Capsule(layers.Layer):
    """
    :param num_capsule: number of capsules in this layer
    :param dim_capsule: dimension of the output vectors of the capsules in this layer
    :param routings: number of iterations for the routing algorithm
    :param share_weights: whether to share weights among capsules
    :param kernel_initializer: initializer for the kernel weights
    :param activation: activation function for the output vectors
    """
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=False,
                 kernel_initializer='glorot_uniform', activation='squash', **kwargs):
        super(Class_Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.kernel_initializer = initializers.get(kernel_initializer)
        if activation == 'squash':
            self.activation = squash
        else:
            self.activation = activations.get(activation)

    def build(self, input_shape):
        assert len(input_shape) >= 3
        input_num_capsule = input_shape[1]
        input_dim_capsule = input_shape[2]
        if self.share_weights:
            self.kernel = self.add_weight(name='capsule_kernel',
                                          shape=(1, input_dim_capsule, self.num_capsule * self.dim_capsule),
                                          initializer=self.kernel_initializer,
                                          trainable=True)
        else:
            self.kernel = self.add_weight(name='capsule_kernel',
                                          shape=(input_num_capsule, input_dim_capsule,
                                                 self.num_capsule * self.dim_capsule),
                                          initializer=self.kernel_initializer,
                                          trainable=True)

    def call(self, inputs, training=None):
        if self.share_weights:
            hat_inputs = K.conv1d(inputs, self.kernel)
        else:
            hat_inputs = K.local_conv1d(inputs, self.kernel, [1], [1])


        batch_size = K.shape(inputs)[0]
        input_num_capsule = K.shape(inputs)[1]
        hat_inputs = K.reshape(hat_inputs,
                               (batch_size, self.num_capsule, input_num_capsule, self.dim_capsule))

        hat_inputs = K.permute_dimensions(hat_inputs, (0, 2, 1, 3))

        b = K.zeros_like(hat_inputs[:, :, 0, :])

        # Begin: Routing algorithm ---------------------------------------------------------------------#
        for i in range(self.routings):
            # # # Simplified routing # # #
            norm_hat_inputs = tf.norm(hat_inputs, axis=-1)
            weighted_hat_inputs = hat_inputs * tf.expand_dims(norm_hat_inputs, axis=-1)
            o = K.sum(weighted_hat_inputs, axis=2) / self.dim_capsule
            o = self.activation(o)

        # End: Routing algorithm -----------------------------------------------------------------------#
        return o

    def compute_output_shape(self, input_shape):
        return tuple([None, self.num_capsule, self.dim_capsule])

    def get_config(self):
        config = {
            'num_capsule': self.num_capsule,
            'dim_capsule': self.dim_capsule,
            'routings': self.routings
        }
        base_config = super(Class_Capsule, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
def PrimaryCap(inputs, dim_capsule, n_channels, kernel_size, strides, padding):
    """
    Apply Conv2D `n_channels` times and concatenate all capsules
    :param inputs: 4D tensor, shape=[None, width, height, channels]
    :param dim_capsule: the dim of the output vector of capsule
    :param n_channels: the number of types of capsules
    :return: output tensor, shape=[None, num_capsule, dim_capsule]
    """
    output = layers.Conv2D(filters=dim_capsule*n_channels, kernel_size=kernel_size, strides=strides, padding=padding,
                           name='primarycap_conv2d')(inputs)
    outputs = layers.Reshape(target_shape=[-1, dim_capsule], name='primarycap_reshape')(output)
    return layers.Lambda(squash, name='primarycap_squash')(outputs)

# %%
with strategy.scope():
    # Get the output of the third convolutional layer
    cnn_output = cnn_model.layers[11].output
    x = Conv2D(filters=128, kernel_size=(7, 7), activation='relu', name='Block5_Conv1')(cnn_output)
    x = Conv2D(filters=128, kernel_size=(6, 6), activation='relu', name='Block5_Conv2')(x)

    # Primary Capsule
    x = PrimaryCap(x, dim_capsule=16, n_channels=2, kernel_size=2, strides=2, padding='valid')

    # Class Capsule Layer
    capsule = Class_Capsule(num_classes, 16, 4, kernel_initializer='glorot_uniform')(x)

    Caps_output = Lambda(lambda z: K.sqrt(K.sum(K.square(z), axis=2)))(capsule)

    #Output = Flatten(name='Output')(Caps_output)  # 14

    #Final_output = Dense(units=2, activation='softmax', name='OutputLayer')(Caps_output)

    CapsNet_model = Model(inputs=cnn_model.input, outputs=Caps_output)

    # Using margin loss
    optimizer = Adam(learning_rate=1e-4) #(0.0001)
    CapsNet_model.compile(loss=margin_loss, optimizer=optimizer, metrics='accuracy')
    CapsNet_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Block1_Conv1_input (InputLa  [(None, 256, 256, 3)]    0
#  yer)
#
#  Block1_Conv1 (Conv2D)       (None, 254, 254, 64)      1792
#
#  Block1_Conv2 (Conv2D)       (None, 252, 252, 64)      36928
#
#  Block1_Pool (MaxPooling2D)  (None, 126, 126, 64)      0
#
#  Block2_Conv1 (Conv2D)       (None, 124, 124, 128)     73856
#
#  Block2_Conv2 (Conv2D)       (None, 122, 122, 128)     147584
#
#  Block2_Pool (MaxPooling2D)  (None, 61, 61, 128)       0
#
#  Block3_Conv1 (Conv2D)       (None, 59, 59, 256)       295168
#
#  Block3_Conv2 (Conv2D)       (None, 57, 57, 256)       590080
#
#  Block3_Pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  Block4_Conv1 (Conv2D)       (None, 26, 26, 256)       590080
#
#  Block4_Pool (MaxPooling2D)  (None, 13, 13, 256)       0
#
#  Block4_Dropout (Dropout)    (None, 13, 13, 256)       0
#
#  Block5_Conv1 (Conv2D)       (None, 7, 7, 128)         1605760
#
#  Block5_Conv2 (Conv2D)       (None, 2, 2, 128)         589952
#
#  primarycap_conv2d (Conv2D)  (None, 1, 1, 32)          16416
#
#  primarycap_reshape (Reshape  (None, 2, 16)            0
#  )
#
#  primarycap_squash (Lambda)  (None, 2, 16)             0
#
#  class__capsule (Class_Capsu  (None, 2, 16)            1024
#  le)
#
#  lambda (Lambda)             (None, 2)                 0
#
# =================================================================
# Total params: 3,948,640
# Trainable params: 3,948,640
# Non-trainable params: 0
# _________________________________________________________________

# %%
with strategy.scope():
  # Create ModelCheckpoint callback for CapsNet model
  CapsNet_checkpoint_path = os.path.join(checkpoint_dir, 'CapsNet_model_checkpoint.h5')
  CapsNet_model_checkpoint = ModelCheckpoint(CapsNet_checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

  # Train the model on the training set
  CapsNet_history = CapsNet_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val), callbacks=[early_stop, val_accuracy_stop, accuracy_stop, CapsNet_model_checkpoint]) #
# Out:
# Epoch 1/50
# 6/8 [=====================>........] - ETA: 0s - loss: 0.2492 - accuracy: 0.5417
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0028s vs `on_train_batch_end` time: 1.2988s). Check your callbacks.
# 8/8 [==============================] - ETA: 0s - loss: 0.2488 - accuracy: 0.5402
# Epoch 1: val_accuracy improved from -inf to 0.54688, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/CapsNet_model_checkpoint.h5
# 8/8 [==============================] - 29s 2s/step - loss: 0.2488 - accuracy: 0.5402 - val_loss: 0.2471 - val_accuracy: 0.5469
# Epoch 2/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2462 - accuracy: 0.5446
# Epoch 2: val_accuracy did not improve from 0.54688
# 8/8 [==============================] - 1s 190ms/step - loss: 0.2461 - accuracy: 0.5374 - val_loss: 0.2452 - val_accuracy: 0.4531
# Epoch 3/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2447 - accuracy: 0.5119
# Epoch 3: val_accuracy did not improve from 0.54688
# 8/8 [==============================] - 1s 177ms/step - loss: 0.2447 - accuracy: 0.5291 - val_loss: 0.2442 - val_accuracy: 0.5312
# Epoch 4/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2440 - accuracy: 0.6731
# Epoch 4: val_accuracy improved from 0.54688 to 0.83594, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/CapsNet_model_checkpoint.h5
# 8/8 [==============================] - 2s 278ms/step - loss: 0.2440 - accuracy: 0.6731 - val_loss: 0.2436 - val_accuracy: 0.8359
# Epoch 5/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2434 - accuracy: 0.8036
# Epoch 5: val_accuracy improved from 0.83594 to 0.88281, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/CapsNet_model_checkpoint.h5
# 8/8 [==============================] - 2s 296ms/step - loss: 0.2434 - accuracy: 0.8116 - val_loss: 0.2429 - val_accuracy: 0.8828
# Epoch 6/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2427 - accuracy: 0.8560
# Epoch 6: val_accuracy did not improve from 0.88281
# 8/8 [==============================] - 2s 248ms/step - loss: 0.2427 - accuracy: 0.8560 - val_loss: 0.2421 - val_accuracy: 0.8750
# Epoch 7/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2420 - accuracy: 0.8670
# Epoch 7: val_accuracy did not improve from 0.88281
# 8/8 [==============================] - 1s 188ms/step - loss: 0.2420 - accuracy: 0.8670 - val_loss: 0.2414 - val_accuracy: 0.8750
# Epoch 8/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2412 - accuracy: 0.8720
# Epoch 8: val_accuracy improved from 0.88281 to 0.89062, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/CapsNet_model_checkpoint.h5
# 8/8 [==============================] - 2s 252ms/step - loss: 0.2412 - accuracy: 0.8698 - val_loss: 0.2405 - val_accuracy: 0.8906
# Epoch 9/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2404 - accuracy: 0.8615
# Epoch 9: val_accuracy did not improve from 0.89062
# 8/8 [==============================] - 1s 185ms/step - loss: 0.2404 - accuracy: 0.8615 - val_loss: 0.2397 - val_accuracy: 0.8906
# Epoch 10/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.8781
# Epoch 10: val_accuracy improved from 0.89062 to 0.89844, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/CapsNet_model_checkpoint.h5
# 8/8 [==============================] - 2s 257ms/step - loss: 0.2395 - accuracy: 0.8781 - val_loss: 0.2389 - val_accuracy: 0.8984
# Epoch 11/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2385 - accuracy: 0.8892
# Epoch 11: val_accuracy did not improve from 0.89844
# 8/8 [==============================] - 1s 182ms/step - loss: 0.2385 - accuracy: 0.8892 - val_loss: 0.2379 - val_accuracy: 0.8984
# Epoch 12/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2375 - accuracy: 0.8958
# Epoch 12: val_accuracy improved from 0.89844 to 0.91406, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/CapsNet_model_checkpoint.h5
# 8/8 [==============================] - 2s 269ms/step - loss: 0.2374 - accuracy: 0.9003 - val_loss: 0.2369 - val_accuracy: 0.9141
# Epoch 13/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2365 - accuracy: 0.9107
# Epoch 13: val_accuracy did not improve from 0.91406
# 8/8 [==============================] - 2s 215ms/step - loss: 0.2364 - accuracy: 0.9086 - val_loss: 0.2364 - val_accuracy: 0.8672
# Epoch 14/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2353 - accuracy: 0.9048
# Epoch 14: val_accuracy did not improve from 0.91406
# 8/8 [==============================] - 2s 212ms/step - loss: 0.2355 - accuracy: 0.8975 - val_loss: 0.2352 - val_accuracy: 0.9062
# Epoch 15/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2344 - accuracy: 0.9226
# Epoch 15: val_accuracy did not improve from 0.91406
# 8/8 [==============================] - 1s 174ms/step - loss: 0.2344 - accuracy: 0.9169 - val_loss: 0.2344 - val_accuracy: 0.8906
# Epoch 16/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2334 - accuracy: 0.9226
# Epoch 16: val_accuracy did not improve from 0.91406
# 8/8 [==============================] - 2s 223ms/step - loss: 0.2334 - accuracy: 0.9197 - val_loss: 0.2336 - val_accuracy: 0.8828
# Epoch 17/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2325 - accuracy: 0.9286
# Epoch 17: val_accuracy did not improve from 0.91406
# 8/8 [==============================] - 1s 179ms/step - loss: 0.2324 - accuracy: 0.9335 - val_loss: 0.2328 - val_accuracy: 0.8828
# Epoch 18/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2313 - accuracy: 0.9464
# Epoch 18: val_accuracy did not improve from 0.91406
# 8/8 [==============================] - 1s 180ms/step - loss: 0.2313 - accuracy: 0.9391 - val_loss: 0.2316 - val_accuracy: 0.9062
# Epoch 19/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2301 - accuracy: 0.9501
# Epoch 19: val_accuracy did not improve from 0.91406
# 8/8 [==============================] - 1s 177ms/step - loss: 0.2301 - accuracy: 0.9501 - val_loss: 0.2308 - val_accuracy: 0.8672
# Epoch 20/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2289 - accuracy: 0.9474
# Epoch 20: val_accuracy improved from 0.91406 to 0.92188, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/CapsNet_model_checkpoint.h5
# 8/8 [==============================] - 2s 332ms/step - loss: 0.2289 - accuracy: 0.9474 - val_loss: 0.2297 - val_accuracy: 0.9219
# Epoch 21/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2278 - accuracy: 0.9494
# Epoch 21: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 200ms/step - loss: 0.2277 - accuracy: 0.9529 - val_loss: 0.2287 - val_accuracy: 0.8828
# Epoch 22/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2264 - accuracy: 0.9494
# Epoch 22: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 196ms/step - loss: 0.2264 - accuracy: 0.9501 - val_loss: 0.2275 - val_accuracy: 0.8984
# Epoch 23/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2250 - accuracy: 0.9584
# Epoch 23: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 2s 216ms/step - loss: 0.2250 - accuracy: 0.9584 - val_loss: 0.2263 - val_accuracy: 0.9141
# Epoch 24/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2237 - accuracy: 0.9613
# Epoch 24: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 175ms/step - loss: 0.2236 - accuracy: 0.9612 - val_loss: 0.2251 - val_accuracy: 0.8906
# Epoch 25/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2223 - accuracy: 0.9702
# Epoch 25: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 180ms/step - loss: 0.2222 - accuracy: 0.9668 - val_loss: 0.2240 - val_accuracy: 0.8906
# Epoch 26/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2209 - accuracy: 0.9673
# Epoch 26: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 182ms/step - loss: 0.2208 - accuracy: 0.9668 - val_loss: 0.2225 - val_accuracy: 0.8984
# Epoch 27/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2191 - accuracy: 0.9668
# Epoch 27: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 2s 202ms/step - loss: 0.2191 - accuracy: 0.9668 - val_loss: 0.2210 - val_accuracy: 0.9062
# Epoch 28/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2173 - accuracy: 0.9702
# Epoch 28: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 2s 244ms/step - loss: 0.2173 - accuracy: 0.9695 - val_loss: 0.2194 - val_accuracy: 0.9141
# Epoch 29/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2159 - accuracy: 0.9702
# Epoch 29: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 177ms/step - loss: 0.2155 - accuracy: 0.9723 - val_loss: 0.2180 - val_accuracy: 0.9062
# Epoch 30/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2139 - accuracy: 0.9732
# Epoch 30: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 2s 214ms/step - loss: 0.2137 - accuracy: 0.9751 - val_loss: 0.2161 - val_accuracy: 0.9219
# Epoch 31/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2116 - accuracy: 0.9792
# Epoch 31: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 2s 206ms/step - loss: 0.2117 - accuracy: 0.9778 - val_loss: 0.2145 - val_accuracy: 0.9062
# Epoch 32/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2098 - accuracy: 0.9762
# Epoch 32: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 2s 207ms/step - loss: 0.2097 - accuracy: 0.9778 - val_loss: 0.2128 - val_accuracy: 0.9062
# Epoch 33/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2077 - accuracy: 0.9762
# Epoch 33: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 195ms/step - loss: 0.2076 - accuracy: 0.9778 - val_loss: 0.2109 - val_accuracy: 0.9062
# Epoch 34/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2055 - accuracy: 0.9778
# Epoch 34: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 181ms/step - loss: 0.2055 - accuracy: 0.9778 - val_loss: 0.2090 - val_accuracy: 0.8984
# Epoch 35/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2033 - accuracy: 0.9806
# Epoch 35: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 181ms/step - loss: 0.2033 - accuracy: 0.9806 - val_loss: 0.2070 - val_accuracy: 0.9062
# Epoch 36/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2010 - accuracy: 0.9806
# Epoch 36: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 177ms/step - loss: 0.2010 - accuracy: 0.9806 - val_loss: 0.2049 - val_accuracy: 0.9062
# Epoch 37/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1989 - accuracy: 0.9792
# Epoch 37: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 180ms/step - loss: 0.1986 - accuracy: 0.9806 - val_loss: 0.2029 - val_accuracy: 0.9062
# Epoch 38/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1962 - accuracy: 0.9806
# Epoch 38: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 179ms/step - loss: 0.1962 - accuracy: 0.9806 - val_loss: 0.2007 - val_accuracy: 0.9062
# Epoch 39/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1934 - accuracy: 0.9881
# Epoch 39: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 180ms/step - loss: 0.1936 - accuracy: 0.9834 - val_loss: 0.1987 - val_accuracy: 0.8984
# Epoch 40/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1912 - accuracy: 0.9821
# Epoch 40: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 2s 207ms/step - loss: 0.1909 - accuracy: 0.9834 - val_loss: 0.1960 - val_accuracy: 0.8906
# Epoch 41/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1882 - accuracy: 0.9834
# Epoch 41: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 2s 207ms/step - loss: 0.1882 - accuracy: 0.9834 - val_loss: 0.1937 - val_accuracy: 0.8984
# Epoch 42/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1858 - accuracy: 0.9821
# Epoch 42: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 2s 217ms/step - loss: 0.1855 - accuracy: 0.9834 - val_loss: 0.1915 - val_accuracy: 0.8984
# Epoch 43/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1829 - accuracy: 0.9821
# Epoch 43: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 174ms/step - loss: 0.1827 - accuracy: 0.9834 - val_loss: 0.1882 - val_accuracy: 0.9219
# Epoch 44/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1798 - accuracy: 0.9851
# Epoch 44: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 181ms/step - loss: 0.1796 - accuracy: 0.9861 - val_loss: 0.1862 - val_accuracy: 0.8984
# Epoch 45/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1768 - accuracy: 0.9851
# Epoch 45: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 179ms/step - loss: 0.1766 - accuracy: 0.9861 - val_loss: 0.1835 - val_accuracy: 0.8906
# Epoch 46/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1737 - accuracy: 0.9881
# Epoch 46: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 178ms/step - loss: 0.1735 - accuracy: 0.9861 - val_loss: 0.1803 - val_accuracy: 0.9141
# Epoch 47/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1704 - accuracy: 0.9861
# Epoch 47: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 184ms/step - loss: 0.1704 - accuracy: 0.9861 - val_loss: 0.1771 - val_accuracy: 0.9141
# Epoch 48/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1674 - accuracy: 0.9851
# Epoch 48: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 2s 257ms/step - loss: 0.1672 - accuracy: 0.9861 - val_loss: 0.1749 - val_accuracy: 0.8984
# Epoch 49/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1639 - accuracy: 0.9861
# Epoch 49: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 1s 193ms/step - loss: 0.1639 - accuracy: 0.9861 - val_loss: 0.1715 - val_accuracy: 0.9141
# Epoch 50/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9889
# Epoch 50: val_accuracy did not improve from 0.92188
# 8/8 [==============================] - 2s 216ms/step - loss: 0.1606 - accuracy: 0.9889 - val_loss: 0.1694 - val_accuracy: 0.8984

# %% [markdown]
# Gabor CapsNet

# %%
class GaborLayer(Layer):
    def __init__(self, filters, kernel_size, strides=(1, 1), activation=None, **kwargs):
        super(GaborLayer, self).__init__(**kwargs)
        self.filters = filters
        self.kernel_size = kernel_size
        self.strides = strides
        self.activation = activation

    def build(self, input_shape):
        input_channels = input_shape[-1]
        self.kernels_real, self.kernels_imag = self._create_gabor_kernels(input_channels)
        self.built = True

    def call(self, inputs):
        # Perform convolution with complex Gabor filters
        conv_real = K.conv2d(inputs, self.kernels_real, strides=self.strides, padding='valid')
        conv_imag = K.conv2d(inputs, self.kernels_imag, strides=self.strides, padding='valid')

        # Combine real and imaginary parts
        output = K.sqrt(K.square(conv_real) + K.square(conv_imag))

        if self.activation is not None:
            output = self.activation(output)
        return output

    def compute_output_shape(self, input_shape):
        output_shape = list(input_shape)
        output_shape[-1] = self.filters
        return tuple(output_shape)

    def _create_gabor_kernels(self, input_channels):
        kernels_real = []
        kernels_imag = []

        # Generate Gabor filters
        for _ in range(self.filters):
            kernel_real, kernel_imag = self._generate_gabor_filter(self.kernel_size, input_channels)
            kernels_real.append(kernel_real)
            kernels_imag.append(kernel_imag)

        # Stack filters along the channel dimension
        kernels_real = K.stack(kernels_real, axis=-1)
        kernels_imag = K.stack(kernels_imag, axis=-1)

        return kernels_real, kernels_imag

    def _generate_gabor_filter(self, kernel_size, input_channels):
        # Create Gabor filter parameters
        sigma = 0.56 * ((kernel_size[0] - 1) * 0.5 - 1) + 0.25
        theta = np.random.uniform(0, np.pi)
        lambda_ = np.random.uniform(0.5, kernel_size[0] - 0.5)
        psi = np.random.uniform(0, np.pi)
        gamma = np.random.uniform(0.5, 1)

        # Generate Gabor filter
        x0 = (kernel_size[0] - 1) // 2
        y0 = (kernel_size[1] - 1) // 2

        y, x = np.mgrid[-x0:x0 + 1, -y0:y0 + 1]
        distance_from_center = np.sqrt(x**2 + y**2)
        mask = np.where(distance_from_center <= min(x0, y0), 1.0, 0.0)

        x_theta = x * np.cos(theta) + y * np.sin(theta)
        y_theta = -x * np.sin(theta) + y * np.cos(theta)

        kernel_real = mask * np.exp(-0.5 * (x_theta ** 2 + gamma ** 2 * y_theta ** 2) / sigma ** 2) \
                      * np.cos(2 * np.pi * x_theta / lambda_ + psi)
        kernel_imag = mask * np.exp(-0.5 * (x_theta ** 2 + gamma ** 2 * y_theta ** 2) / sigma ** 2) \
                      * np.sin(2 * np.pi * x_theta / lambda_ + psi)

        # Reshape the kernels to match the input channel dimensions
        kernel_real = kernel_real.reshape((kernel_size[0], kernel_size[1], 1))
        kernel_imag = kernel_imag.reshape((kernel_size[0], kernel_size[1], 1))

        # Repeat the kernels for each input channel
        kernel_real = np.repeat(kernel_real, input_channels, axis=-1)
        kernel_imag = np.repeat(kernel_imag, input_channels, axis=-1)

        # Convert the kernels to tensors
        kernel_real = K.constant(kernel_real, dtype=K.floatx())
        kernel_imag = K.constant(kernel_imag, dtype=K.floatx())

        return kernel_real, kernel_imag

    def get_config(self):
        config = super().get_config()
        config.update({
            "filters": self.filters,
            "kernel_size": self.kernel_size,
            "strides": self.strides,
            "activation": self.activation,
         })
        return config

# %%
with strategy.scope():
  # Get the output of the third convolutional layer
  cnn_output = cnn_model.layers[11].output
  x = Conv2D(filters=128, kernel_size=(7, 7), activation='relu', name='Block5_Conv1')(cnn_output)
  print('X: ', x.shape)

  gabor_layer = GaborLayer(filters=128, kernel_size=(5, 5), strides=(1, 1), activation=K.relu, name='GaborLayer')(x)

  #Primary Capsule
  x = PrimaryCap(gabor_layer, dim_capsule=16, n_channels=2, kernel_size=2, strides=2, padding='valid')

  # Secondary Capsule Layer
  capsule = Class_Capsule(num_classes, 16, 4, True)(x)
  Caps_output = Lambda(lambda z: K.sqrt(K.sum(K.square(z), axis=2)))(capsule)

  #Output_flattened = Flatten(name='Output')(capsule)

  #Final_output = Dense(units=2, activation='softmax', name='OutputLayer')(Output_flattened)

  # Create the combined model
  GCN_model = Model(inputs=cnn_model.input, outputs=Caps_output)

  # Using margin loss
  optimizer = Adam(learning_rate=1e-4) #(0.0001)

  # Compile the model
  GCN_model.compile(loss=margin_loss, optimizer=optimizer, metrics='accuracy')

  # Model summary
  GCN_model.summary() #
# Out:
# X:  (None, 7, 7, 128)
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Block1_Conv1_input (InputLa  [(None, 256, 256, 3)]    0
#  yer)
#
#  Block1_Conv1 (Conv2D)       (None, 254, 254, 64)      1792
#
#  Block1_Conv2 (Conv2D)       (None, 252, 252, 64)      36928
#
#  Block1_Pool (MaxPooling2D)  (None, 126, 126, 64)      0
#
#  Block2_Conv1 (Conv2D)       (None, 124, 124, 128)     73856
#
#  Block2_Conv2 (Conv2D)       (None, 122, 122, 128)     147584
#
#  Block2_Pool (MaxPooling2D)  (None, 61, 61, 128)       0
#
#  Block3_Conv1 (Conv2D)       (None, 59, 59, 256)       295168
#
#  Block3_Conv2 (Conv2D)       (None, 57, 57, 256)       590080
#
#  Block3_Pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  Block4_Conv1 (Conv2D)       (None, 26, 26, 256)       590080
#
#  Block4_Pool (MaxPooling2D)  (None, 13, 13, 256)       0
#
#  Block4_Dropout (Dropout)    (None, 13, 13, 256)       0
#
#  Block5_Conv1 (Conv2D)       (None, 7, 7, 128)         1605760
#
#  GaborLayer (GaborLayer)     (None, 3, 3, 128)         0
#
#  primarycap_conv2d (Conv2D)  (None, 1, 1, 32)          16416
#
#  primarycap_reshape (Reshape  (None, 2, 16)            0
#  )
#
#  primarycap_squash (Lambda)  (None, 2, 16)             0
#
#  class__capsule_1 (Class_Cap  (None, 2, 16)            512
#  sule)
#
#  lambda_1 (Lambda)           (None, 2)                 0
#
# =================================================================
# Total params: 3,358,176
# Trainable params: 3,358,176
# Non-trainable params: 0
# _________________________________________________________________

# %%
with strategy.scope():
  # Define the EarlyStopping callback
  early_stop = EarlyStopping(monitor='accuracy', patience=25, verbose=1, mode='max')

  # Create ModelCheckpoint callback for CapsNet model
  GCN_checkpoint_path = os.path.join(checkpoint_dir, 'GCN_model_checkpoint.h5')
  GCN_model_checkpoint = ModelCheckpoint(GCN_checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

  # Train the model on the training set
  GCN_history = GCN_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val), callbacks= [val_accuracy_stop, accuracy_stop, GCN_model_checkpoint]) #early_stop,
# Out:
# Epoch 1/50
# 6/8 [=====================>........] - ETA: 0s - loss: 0.2471 - accuracy: 0.5243
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0028s vs `on_train_batch_end` time: 1.2709s). Check your callbacks.
# 8/8 [==============================] - ETA: 0s - loss: 0.2469 - accuracy: 0.5402
# Epoch 1: val_accuracy improved from -inf to 0.70312, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/GCN_model_checkpoint.h5
# 8/8 [==============================] - 28s 2s/step - loss: 0.2469 - accuracy: 0.5402 - val_loss: 0.2449 - val_accuracy: 0.7031
# Epoch 2/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2434 - accuracy: 0.6339
# Epoch 2: val_accuracy did not improve from 0.70312
# 8/8 [==============================] - 1s 183ms/step - loss: 0.2433 - accuracy: 0.6343 - val_loss: 0.2406 - val_accuracy: 0.6875
# Epoch 3/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2386 - accuracy: 0.7292
# Epoch 3: val_accuracy improved from 0.70312 to 0.79688, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/GCN_model_checkpoint.h5
# 8/8 [==============================] - 2s 240ms/step - loss: 0.2384 - accuracy: 0.7313 - val_loss: 0.2348 - val_accuracy: 0.7969
# Epoch 4/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2322 - accuracy: 0.7768
# Epoch 4: val_accuracy improved from 0.79688 to 0.82812, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/GCN_model_checkpoint.h5
# 8/8 [==============================] - 2s 242ms/step - loss: 0.2319 - accuracy: 0.7784 - val_loss: 0.2279 - val_accuracy: 0.8281
# Epoch 5/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2249 - accuracy: 0.8065
# Epoch 5: val_accuracy did not improve from 0.82812
# 8/8 [==============================] - 1s 199ms/step - loss: 0.2245 - accuracy: 0.8061 - val_loss: 0.2215 - val_accuracy: 0.6641
# Epoch 6/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2180 - accuracy: 0.7202
# Epoch 6: val_accuracy did not improve from 0.82812
# 8/8 [==============================] - 1s 193ms/step - loss: 0.2180 - accuracy: 0.7036 - val_loss: 0.2172 - val_accuracy: 0.6172
# Epoch 7/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2135 - accuracy: 0.6369
# Epoch 7: val_accuracy did not improve from 0.82812
# 8/8 [==============================] - 2s 221ms/step - loss: 0.2133 - accuracy: 0.6371 - val_loss: 0.2141 - val_accuracy: 0.5469
# Epoch 8/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2101 - accuracy: 0.5651
# Epoch 8: val_accuracy did not improve from 0.82812
# 8/8 [==============================] - 1s 173ms/step - loss: 0.2101 - accuracy: 0.5651 - val_loss: 0.2114 - val_accuracy: 0.5781
# Epoch 9/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2076 - accuracy: 0.6399
# Epoch 9: val_accuracy did not improve from 0.82812
# 8/8 [==============================] - 2s 242ms/step - loss: 0.2071 - accuracy: 0.6482 - val_loss: 0.2085 - val_accuracy: 0.6797
# Epoch 10/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2041 - accuracy: 0.7768
# Epoch 10: val_accuracy did not improve from 0.82812
# 8/8 [==============================] - 1s 181ms/step - loss: 0.2039 - accuracy: 0.7812 - val_loss: 0.2056 - val_accuracy: 0.7188
# Epoch 11/50
# 8/8 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.8421
# Epoch 11: val_accuracy did not improve from 0.82812
# 8/8 [==============================] - 1s 196ms/step - loss: 0.2005 - accuracy: 0.8421 - val_loss: 0.2024 - val_accuracy: 0.7891
# Epoch 12/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1967 - accuracy: 0.8781
# Epoch 12: val_accuracy did not improve from 0.82812
# 8/8 [==============================] - 1s 189ms/step - loss: 0.1967 - accuracy: 0.8781 - val_loss: 0.1995 - val_accuracy: 0.8203
# Epoch 13/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1929 - accuracy: 0.9197
# Epoch 13: val_accuracy did not improve from 0.82812
# 8/8 [==============================] - 1s 179ms/step - loss: 0.1929 - accuracy: 0.9197 - val_loss: 0.1967 - val_accuracy: 0.8281
# Epoch 14/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1891 - accuracy: 0.9405
# Epoch 14: val_accuracy improved from 0.82812 to 0.85938, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/GCN_model_checkpoint.h5
# 8/8 [==============================] - 2s 308ms/step - loss: 0.1891 - accuracy: 0.9418 - val_loss: 0.1937 - val_accuracy: 0.8594
# Epoch 15/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1852 - accuracy: 0.9501
# Epoch 15: val_accuracy did not improve from 0.85938
# 8/8 [==============================] - 2s 208ms/step - loss: 0.1852 - accuracy: 0.9501 - val_loss: 0.1917 - val_accuracy: 0.8359
# Epoch 16/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1817 - accuracy: 0.9583
# Epoch 16: val_accuracy improved from 0.85938 to 0.86719, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/GCN_model_checkpoint.h5
# 8/8 [==============================] - 2s 278ms/step - loss: 0.1814 - accuracy: 0.9612 - val_loss: 0.1885 - val_accuracy: 0.8672
# Epoch 17/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1786 - accuracy: 0.9612
# Epoch 17: val_accuracy improved from 0.86719 to 0.87500, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/GCN_model_checkpoint.h5
# 8/8 [==============================] - 2s 253ms/step - loss: 0.1786 - accuracy: 0.9612 - val_loss: 0.1863 - val_accuracy: 0.8750
# Epoch 18/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1751 - accuracy: 0.9792
# Epoch 18: val_accuracy did not improve from 0.87500
# 8/8 [==============================] - 1s 181ms/step - loss: 0.1751 - accuracy: 0.9778 - val_loss: 0.1841 - val_accuracy: 0.8750
# Epoch 19/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1723 - accuracy: 0.9834
# Epoch 19: val_accuracy did not improve from 0.87500
# 8/8 [==============================] - 1s 180ms/step - loss: 0.1723 - accuracy: 0.9834 - val_loss: 0.1817 - val_accuracy: 0.8750
# Epoch 20/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1694 - accuracy: 0.9821
# Epoch 20: val_accuracy did not improve from 0.87500
# 8/8 [==============================] - 1s 182ms/step - loss: 0.1691 - accuracy: 0.9834 - val_loss: 0.1811 - val_accuracy: 0.8750
# Epoch 21/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1666 - accuracy: 0.9821
# Epoch 21: val_accuracy did not improve from 0.87500
# 8/8 [==============================] - 1s 185ms/step - loss: 0.1664 - accuracy: 0.9834 - val_loss: 0.1792 - val_accuracy: 0.8750
# Epoch 22/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1637 - accuracy: 0.9911
# Epoch 22: val_accuracy improved from 0.87500 to 0.88281, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/GCN_model_checkpoint.h5
# 8/8 [==============================] - 2s 240ms/step - loss: 0.1638 - accuracy: 0.9889 - val_loss: 0.1763 - val_accuracy: 0.8828
# Epoch 23/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.9889
# Epoch 23: val_accuracy did not improve from 0.88281
# 8/8 [==============================] - 1s 202ms/step - loss: 0.1611 - accuracy: 0.9889 - val_loss: 0.1747 - val_accuracy: 0.8828
# Epoch 24/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1584 - accuracy: 0.9889
# Epoch 24: val_accuracy improved from 0.88281 to 0.91406, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/GCN_model_checkpoint.h5
# 8/8 [==============================] - 2s 290ms/step - loss: 0.1584 - accuracy: 0.9889 - val_loss: 0.1720 - val_accuracy: 0.9141
# Epoch 25/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1557 - accuracy: 0.9917
# Epoch 25: val_accuracy did not improve from 0.91406
# 8/8 [==============================] - 2s 209ms/step - loss: 0.1557 - accuracy: 0.9917 - val_loss: 0.1691 - val_accuracy: 0.8906
# Epoch 26/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1533 - accuracy: 0.9911
# Epoch 26: val_accuracy did not improve from 0.91406
# 8/8 [==============================] - 1s 180ms/step - loss: 0.1531 - accuracy: 0.9917 - val_loss: 0.1673 - val_accuracy: 0.9062
# Epoch 27/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1504 - accuracy: 0.9972
# Epoch 27: val_accuracy did not improve from 0.91406
# 8/8 [==============================] - 1s 189ms/step - loss: 0.1504 - accuracy: 0.9972 - val_loss: 0.1642 - val_accuracy: 0.9141
# Epoch 28/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1479 - accuracy: 0.9972
# Epoch 28: val_accuracy did not improve from 0.91406
# 8/8 [==============================] - 1s 178ms/step - loss: 0.1479 - accuracy: 0.9972 - val_loss: 0.1624 - val_accuracy: 0.9062
# Epoch 29/50
# 8/8 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9972
# Epoch 29: val_accuracy did not improve from 0.91406
# 8/8 [==============================] - 1s 187ms/step - loss: 0.1454 - accuracy: 0.9972 - val_loss: 0.1604 - val_accuracy: 0.8984
# Epoch 30/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1427 - accuracy: 0.9970
# Epoch 30: val_accuracy improved from 0.91406 to 0.93750, saving model to /content/drive/MyDrive/Model_Checkpoints/Projects/Glaucoma_Detection/GCN_model_checkpoint.h5
# 8/8 [==============================] - 2s 264ms/step - loss: 0.1426 - accuracy: 0.9972 - val_loss: 0.1573 - val_accuracy: 0.9375
# Epoch 31/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1402 - accuracy: 0.9970
# Epoch 31: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 182ms/step - loss: 0.1401 - accuracy: 0.9972 - val_loss: 0.1567 - val_accuracy: 0.8906
# Epoch 32/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1375 - accuracy: 0.9970
# Epoch 32: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 2s 207ms/step - loss: 0.1374 - accuracy: 0.9972 - val_loss: 0.1554 - val_accuracy: 0.8906
# Epoch 33/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1351 - accuracy: 0.9970
# Epoch 33: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 2s 208ms/step - loss: 0.1349 - accuracy: 0.9972 - val_loss: 0.1525 - val_accuracy: 0.8828
# Epoch 34/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1324 - accuracy: 0.9970
# Epoch 34: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 2s 209ms/step - loss: 0.1321 - accuracy: 0.9972 - val_loss: 0.1513 - val_accuracy: 0.8750
# Epoch 35/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1298 - accuracy: 0.9970
# Epoch 35: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 187ms/step - loss: 0.1297 - accuracy: 0.9972 - val_loss: 0.1498 - val_accuracy: 0.8672
# Epoch 36/50
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1267 - accuracy: 1.0000Stopping training as accuracy reached 1.0%.
#
# Epoch 36: val_accuracy did not improve from 0.93750
# 8/8 [==============================] - 1s 184ms/step - loss: 0.1268 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.8516

# %%
# Define the function to generate class activation maps using Grad-CAM
def generate_cam(model, img, class_index, layer_name):
    img = np.expand_dims(img, axis=0)
    grad_model = Model(inputs=model.inputs, outputs=(model.get_layer(layer_name).output, model.output))

    with tf.GradientTape() as tape:
        conv_output, predictions = grad_model(img)
        class_output = predictions[:, class_index]

    grads = tape.gradient(class_output, conv_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_output = conv_output[0].numpy()

    for i in range(conv_output.shape[-1]):
        conv_output[:, :, i] *= pooled_grads[i]

    heatmap = np.mean(conv_output, axis=-1)
    heatmap = np.maximum(heatmap, 0)
    heatmap /= np.max(heatmap)

    return heatmap

# %%
# Convert data_dir to a string
data_dir = str(data_dir)

# Get image filenames for each class
normal_img = [fn for fn in os.listdir(os.path.join(data_dir, 'Normal')) if fn == 'r1_Im040.png']
glaucoma_img = [fn for fn in os.listdir(os.path.join(data_dir, 'Glaucoma')) if fn == 'r2_Im302.png']

# Combine the image filenames for both classes
image_filenames = normal_img + glaucoma_img

# Get class indices and names
class_indices = {'Normal': 0, 'Glaucoma': 1}
class_names = list(class_indices.keys())

# Generate Grad-CAM for one image from each class
for image_filename in image_filenames:
    # Determine the class based on the image filename
    class_name = 'Glaucoma' if image_filename in glaucoma_img else 'Normal'
    class_index = class_indices[class_name]

    # Find the full image path
    image_path = os.path.join(data_dir, class_name, image_filename)
    img = cv2.imread(image_path)
    img = cv2.resize(img, (X_train.shape[1], X_train.shape[2]))
    img = img / 255.0  # Normalize the image

    print('Class index: ', class_index)

    # Generate CAM for CNN model
    cam_cnn = generate_cam(cnn_model, img, class_index, 'Block4_Conv1')

    # Generate CAM for CapsNet model
    cam_capsnet = generate_cam(CapsNet_model, img, class_index, 'Block4_Conv1')

    # Generate CAM for GCN model
    cam_gcn = generate_cam(GCN_model, img, class_index, 'Block4_Conv1')

   # Ensure the heatmap has non-zero values before normalization
    if np.max(cam_cnn) != 0:
        cam_cnn /= np.max(cam_cnn)
    else:
        cam_cnn = np.zeros_like(cam_cnn)


    if np.max(cam_capsnet) != 0:
        cam_capsnet /= np.max(cam_capsnet)
    else:
      cam_capsnet = np.zeros_like(cam_capsnet)

    if np.max(cam_gcn) != 0:
        cam_gcn /= np.max(cam_gcn)
    else:
      cam_gcn = np.zeros_like(cam_gcn)

    # Plot the original image and overlaid CAMs
    plt.figure(figsize=(18, 4))
    plt.subplot(141)
    plt.imshow(img[:, :, ::-1])
    plt.title(f'Original Image - {class_name}')
    plt.axis('off')

    plt.subplot(142)
    plt.imshow(img[:, :, ::-1])
    plt.imshow(cam_cnn, cmap='jet', alpha=0.5)
    plt.title(f'CNN CAM - {class_name}')
    plt.axis('off')

    plt.subplot(143)
    plt.imshow(img[:, :, ::-1])
    plt.imshow(cam_capsnet, cmap='jet', alpha=0.5)
    plt.title(f'CapsNet CAM - {class_name}')
    plt.axis('off')

    plt.subplot(144)
    plt.imshow(img[:, :, ::-1])
    plt.imshow(cam_gcn, cmap='jet', alpha=0.5)
    plt.title(f'GCN CAM - {class_name}')
    plt.axis('off')

    plt.show()
# Out:
# Class index:  0
# Class index:  1

# %% [markdown]
# #**EVALUATION**

# %% [markdown]
# 1. Evaluation on Testing set

# %%
# CNN model evaluation
y_pred_cnn = cnn_model.predict(X_test)
y_pred_cnn_binary = (y_pred_cnn > 0.5).astype(int)
cnn_test_loss, cnn_test_acc = cnn_model.evaluate(X_test, y_test, verbose=0)
cnn_test_auc_score = roc_auc_score(y_test, y_pred_cnn)

# CapsNet model evaluation
y_pred_capsnet = CapsNet_model.predict(X_test)
y_pred_capsnet_binary = (y_pred_capsnet > 0.5).astype(int)
capsnet_test_loss, capsnet_test_acc = CapsNet_model.evaluate(X_test, y_test, verbose=0)
capsnet_test_auc_score = roc_auc_score(y_test, y_pred_capsnet)

# GCN model evaluation
y_pred_gcn = GCN_model.predict(X_test)
y_pred_gcn_binary = (y_pred_gcn > 0.5).astype(int)
gcn_test_loss, gcn_test_acc = GCN_model.evaluate(X_test, y_test, verbose=0)
gcn_test_auc_score = roc_auc_score(y_test, y_pred_gcn)
# Out:
# 5/5 [==============================] - 8s 2s/step
# 5/5 [==============================] - 8s 2s/step
# 5/5 [==============================] - 8s 2s/step

# %%
with strategy.scope():
  # Plotting accuracies
  plt.plot(CNN_history.history['accuracy'], label='Training_CNN', color='blue')
  plt.plot(CapsNet_history.history['accuracy'], label='Training_CapsNet', color='green')
  plt.plot(GCN_history.history['accuracy'], label='Training_GCN', color='red')
  plt.title('Model Accuracies')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

# %%
with strategy.scope():
  # Plotting losses
  plt.plot(CNN_history.history['loss'], label='Training_CNN', color='blue')
  plt.plot(CapsNet_history.history['loss'], label='Training_CapsNet', color='green')
  plt.plot(GCN_history.history['loss'], label='Training_GCN', color='red')
  plt.title('Model Losses')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend()
  plt.show()

# %% [markdown]
# 2.   Evaluation on Validation Set

# %%
# CNN model evaluation
y_val_pred_cnn = cnn_model.predict(X_val)
y_val_pred_cnn_binary = (y_val_pred_cnn > 0.5).astype(int)
cnn_val_loss, cnn_val_acc = cnn_model.evaluate(X_val, y_val, verbose=0)
cnn_val_auc_score = roc_auc_score(y_val, y_val_pred_cnn)

# CapsNet model evaluation
y_val_pred_capsnet = CapsNet_model.predict(X_val)
y_val_pred_capsnet_binary = (y_val_pred_capsnet > 0.5).astype(int)
capsnet_val_loss, capsnet_val_acc = CapsNet_model.evaluate(X_val, y_val, verbose=0)
capsnet_val_auc_score = roc_auc_score(y_val, y_val_pred_capsnet)

# GCN model evaluation
y_val_pred_gcn = GCN_model.predict(X_val)
y_val_pred_gcn_binary = (y_val_pred_gcn > 0.5).astype(int)
gcn_val_loss, gcn_val_acc = GCN_model.evaluate(X_val, y_val, verbose=0)
gcn_val_auc_score = roc_auc_score(y_val, y_val_pred_gcn)
# Out:
# 4/4 [==============================] - 1s 36ms/step
# 4/4 [==============================] - 1s 36ms/step
# 4/4 [==============================] - 2s 45ms/step

# %%
with strategy.scope():
  # Plotting accuracies
  plt.plot(CNN_history.history['val_accuracy'], label='Validation_CNN', color='blue')
  plt.plot(CapsNet_history.history['val_accuracy'], label='Validation_CapsNet', color='green')
  plt.plot(GCN_history.history['val_accuracy'], label='Validation_GCN', color='red')
  plt.title('Model Accuracies')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend()
  plt.axis('off')
  plt.show()

# %%
with strategy.scope():
  # Plotting losses
  plt.plot(CNN_history.history['val_loss'], label='Validation_CNN', color='blue')
  plt.plot(CapsNet_history.history['val_loss'], label='Validation_CapsNet', color='green')
  plt.plot(GCN_history.history['val_loss'], label='Validation_GCN', color='red')
  plt.title('Model Losses')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend()
  plt.axis('off')
  plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Plotting ROC curve for class 0
fpr, tpr, _ = roc_curve(y_test[:, 0], y_pred_cnn[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label='CNN', color='blue')

fpr, tpr, _ = roc_curve(y_test[:, 0], y_pred_capsnet[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label='CapsNet', color='green')

fpr, tpr, _ = roc_curve(y_test[:, 0], y_pred_gcn[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label='GCN', color='red')

plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
# Plotting ROC curve for class 0
fpr, tpr, _ = roc_curve(y_val[:, 0], y_val_pred_cnn[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label='CNN', color='blue')

fpr, tpr, _ = roc_curve(y_val[:, 0], y_val_pred_capsnet[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label='CapsNet', color='green')

fpr, tpr, _ = roc_curve(y_val[:, 0], y_val_pred_gcn[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label='GCN', color='red')

plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.axis('off')
plt.show()

# %%
# Print evaluation results
print('#----------------------------------------------------------------------------------------#')
print('EVALUATION OF MODELS (TESTING)')
print('#----------------------------------------------------------------------------------------#')

print('1')
print('CONVOLUTIONAL NEURAL NETWORK:')
print("Accuracy:", cnn_test_acc)
print("Loss:", cnn_test_loss)
print('AUC Score: ', cnn_test_auc_score)
print('')

print('2')
print('***CAPSULE NETWORK***')
print("Accuracy:", capsnet_test_acc)
print("Loss:", capsnet_test_loss)
print('AUC Score: ', capsnet_test_auc_score)
print('')

print('3')
print('***GABOR CAPSULE NETWORK***')
print("Accuracy:", gcn_test_acc)
print("Loss:", gcn_test_loss)
print('AUC Score: ', gcn_test_auc_score)
print('')
print('#----------------------------------------------------------------------------------------#')
# Out:
# #----------------------------------------------------------------------------------------#
# EVALUATION OF MODELS (TESTING)
# #----------------------------------------------------------------------------------------#
# 1
# CONVOLUTIONAL NEURAL NETWORK:
# Accuracy: 0.8449612259864807
# Loss: 2.6379506587982178
# AUC Score:  0.9150216658642272
#
# 2
# ***CAPSULE NETWORK***
# Accuracy: 0.8527131676673889
# Loss: 0.17257431149482727
# AUC Score:  0.9223639865190179
#
# 3
# ***GABOR CAPSULE NETWORK***
# Accuracy: 0.7441860437393188
# Loss: 0.15790864825248718
# AUC Score:  0.8890226287915262
#
# #----------------------------------------------------------------------------------------#

# %%
# Print evaluation results
print('#----------------------------------------------------------------------------------------#')
print('EVALUATION OF MODELS (VALIDATION)')
print('#----------------------------------------------------------------------------------------#')

print('1')
print('CONVOLUTIONAL NEURAL NETWORK:')
print("Accuracy:", cnn_val_acc)
print("Loss:", cnn_val_loss)
print('AUC Score: ', cnn_val_auc_score)
print('')

print('2')
print('***CAPSULE NETWORK***')
print("Accuracy:", capsnet_val_acc)
print("Loss:", capsnet_val_loss)
print('AUC Score: ', capsnet_val_auc_score)
print('')

print('3')
print('***GABOR CAPSULE NETWORK***')
print("Accuracy:", gcn_val_acc)
print("Loss:", gcn_val_loss)
print('AUC Score: ', gcn_val_auc_score)
print('')
print('#----------------------------------------------------------------------------------------#')
# Out:
# #----------------------------------------------------------------------------------------#
# EVALUATION OF MODELS (VALIDATION)
# #----------------------------------------------------------------------------------------#
# 1
# CONVOLUTIONAL NEURAL NETWORK:
# Accuracy: 0.8671875
# Loss: 1.963022232055664
# AUC Score:  0.9263546798029556
#
# 2
# ***CAPSULE NETWORK***
# Accuracy: 0.8984375
# Loss: 0.16990236937999725
# AUC Score:  0.9331280788177341
#
# 3
# ***GABOR CAPSULE NETWORK***
# Accuracy: 0.8515625
# Loss: 0.14734356105327606
# AUC Score:  0.9384236453201971
#
# #----------------------------------------------------------------------------------------#

# %% [markdown]
# #**Confusion Matrices**

# %%
with strategy.scope():

    # Get true labels from y_test
    y_true_labels = np.argmax(y_test, axis=1)

    # Convert predictions to labels
    y_pred_cnn_labels = np.argmax(y_pred_cnn, axis=1)
    y_pred_capsnet_labels = np.argmax(y_pred_capsnet, axis=1)
    y_pred_gcn_labels = np.argmax(y_pred_gcn, axis=1)

    # Error Analysis
    for i in range(0, len(y_test)):
        true_label = np.argmax(y_test[i])
        cnn_prediction = np.argmax(y_pred_cnn[i])
        capsnet_prediction = np.argmax(y_pred_capsnet[i])
        gcn_prediction = np.argmax(y_pred_gcn[i])

        if true_label != cnn_prediction or true_label != capsnet_prediction or true_label != gcn_prediction:
            print("True Label:", true_label)
            print("CNN Prediction:", cnn_prediction)
            print("CapsNet Prediction:", capsnet_prediction)
            print("GCN Prediction:", gcn_prediction)
            print("---------------------------------")
# Out:
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 1
# ---------------------------------
# True Label: 1
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 0
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 1
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 1
# CNN Prediction: 1
# CapsNet Prediction: 0
# GCN Prediction: 0
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 1
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 0
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 1
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 0
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 1
# GCN Prediction: 0
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 1
# CNN Prediction: 0
# CapsNet Prediction: 1
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 1
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 0
# ---------------------------------
# True Label: 1
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 1
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 0
# GCN Prediction: 0
# ---------------------------------
# True Label: 1
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 0
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 0
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 1
# ---------------------------------
# True Label: 0
# CNN Prediction: 1
# CapsNet Prediction: 1
# GCN Prediction: 1
# ---------------------------------
# True Label: 1
# CNN Prediction: 0
# CapsNet Prediction: 0
# GCN Prediction: 0
# ---------------------------------

# %%
# Define a function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, classes, title):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.set(font_scale=1.2)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
                xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(title)
    plt.show()

# %%
with strategy.scope():
  # Plot confusion matrices
  classes = np.arange(y_test.shape[1])
  plot_confusion_matrix(y_true_labels, y_pred_cnn_labels, classes, title='CNN Confusion Matrix')
  plot_confusion_matrix(y_true_labels, y_pred_capsnet_labels, classes, title='CapsNet Confusion Matrix')
  plot_confusion_matrix(y_true_labels, y_pred_gcn_labels, classes, title='GCN Confusion Matrix')

# %% [markdown]
# #**Testing and Inferencing**

# %%
# Directory containing the images for inference
images_directory = '/content/drive/MyDrive/Colab Notebooks/Projects/Final(Undergraduate)/ACRIMA_inference'

# Function to load and preprocess an image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((X_train.shape[1], X_train.shape[2]))
    image = np.array(image) / 255.0  # Normalize the image
    return image

# Iterate through all image files in the directory
for filename in os.listdir(images_directory):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        image_path = os.path.join(images_directory, filename)
        test_image = preprocess_image(image_path)

        with strategy.scope():
            # CNN model classification
            cnn_prediction = cnn_model.predict(np.expand_dims(test_image, axis=0))
            cnn_prediction_label = np.argmax(cnn_prediction)
            cnn_prediction_name = class_names[cnn_prediction_label]

            # CapsNet model classification
            capsnet_prediction = CapsNet_model.predict(np.expand_dims(test_image, axis=0))
            capsnet_prediction_label = np.argmax(capsnet_prediction)
            capsnet_prediction_name = class_names[capsnet_prediction_label]

            # GCN model classification
            gcn_prediction = GCN_model.predict(np.expand_dims(test_image, axis=0))
            gcn_prediction_label = np.argmax(gcn_prediction)
            gcn_prediction_name = class_names[gcn_prediction_label]

        # Display the image
        plt.imshow(test_image)
        plt.axis('off')
        plt.show()

        # Print classifications
        print("Image:", filename)
        print("CNN Model Classification:", cnn_prediction_name)
        print("CapsNet Model Classification:", capsnet_prediction_name)
        print("GCN Model Classification:", gcn_prediction_name)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 876ms/step
# 1/1 [==============================] - 2s 2s/step
# Image: g0.png
# CNN Model Classification: Glaucoma
# CapsNet Model Classification: Glaucoma
# GCN Model Classification: Glaucoma
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# Image: n0.png
# CNN Model Classification: Normal
# CapsNet Model Classification: Normal
# GCN Model Classification: Normal

# %% [markdown]
# # **Saving and Converting best model**

# %%
with strategy.scope():
  cnn_save_path = '/content/drive/MyDrive/Colab Notebooks/Projects/Final(Undergraduate)/New/model.h5'
  save_model(cnn_model, cnn_save_path)

# %%
# Load the saved model without compiling it
model = tf.keras.models.load_model(cnn_save_path, compile=False)

# Convert the model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TensorFlow Lite model
tflite_model_path = '/content/drive/MyDrive/Colab Notebooks/Projects/Final(Undergraduate)/New/CNN_tflite/model.tflite'
with open(tflite_model_path, 'wb') as f:
    f.write(tflite_model)

print('Model converted and saved as TensorFlow Lite:', tflite_model_path)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Block1_Conv1_input with unsupported characters which will be renamed to block1_conv1_input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Model converted and saved as TensorFlow Lite: /content/drive/MyDrive/Colab Notebooks/Projects/Final(Undergraduate)/New/CNN_tflite/model.tflite

# %%
with strategy.scope():
    # Specify the path to save the best model
    save_path = '/content/drive/MyDrive/Colab Notebooks/Projects/Final(Undergraduate)/New/savedModels/model.h5'

    # Determine the best model based on a chosen metric (e.g., accuracy and loss)
    best_model_name = None
    best_accuracy = 0.0
    best_loss = float('inf')

    # Check if the CNN model has the best metric
    if cnn_test_acc > best_accuracy and cnn_test_loss < best_loss:
        best_accuracy = cnn_test_acc
        best_loss = cnn_test_loss
        best_model_name = 'CNN model'
        save_model(cnn_model, save_path)  # Save the best CNN model

    # Check if the CapsNet model has the best metric
    if capsnet_test_acc > best_accuracy and capsnet_test_loss < best_loss:
        best_accuracy = capsnet_test_acc
        best_loss = capsnet_test_loss
        best_model_name = 'Capsnet model'
        save_model(CapsNet_model, save_path)  # Save the best CapsNet model

    # Check if the GCN model has the best metric
    if gcn_test_acc > best_accuracy and gcn_test_loss < best_loss:
        best_accuracy = gcn_test_acc
        best_loss = gcn_test_loss
        best_model_name = 'Gabor CapsNet model'
        save_model(GCN_model, save_path)  # Save the best GCN model

    # Define the path for the labels file
    labels_file_path = '/content/drive/MyDrive/Colab Notebooks/Projects/Final(Undergraduate)/New/tflite/labels.txt'

    # Save the labels and class names as a .txt file
    with open(labels_file_path, 'w') as f:
        for class_name, label_idx in train_generator.class_indices.items():
            f.write(class_name + '(' + str(label_idx) + ')' + '\n')

    print('Labels and class names saved as .txt:', labels_file_path)

# Print the details of the best model
print('Best Model:')
print('Accuracy:', best_accuracy)
print('Loss:', best_loss)
print('Model Name:', best_model_name)
# Out:
# Labels and class names saved as .txt: /content/drive/MyDrive/Colab Notebooks/Projects/Final(Undergraduate)/New/tflite/labels.txt
# Best Model:
# Accuracy: 0.8527131676673889
# Loss: 0.17257431149482727
# Model Name: Capsnet model

# %%
# Load the saved model without compiling it
saved_model_path = '/content/drive/MyDrive/Colab Notebooks/Projects/Final(Undergraduate)/New/savedModels/model.h5'

# Define the custom objects dictionary for loading custom layers
custom_objects = {'Class_Capsule': Class_Capsule, 'margin_loss': margin_loss, 'squash': squash}

# Load the saved model with custom layers and loss function
model = tf.keras.models.load_model(saved_model_path, custom_objects=custom_objects, compile=False)

# Convert the model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TensorFlow Lite model
tflite_model_path = '/content/drive/MyDrive/Colab Notebooks/Projects/Final(Undergraduate)/New/tflite/model.tflite'
with open(tflite_model_path, 'wb') as f:
    f.write(tflite_model)

print('Model converted and saved as TensorFlow Lite:', tflite_model_path)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Block1_Conv1_input with unsupported characters which will be renamed to block1_conv1_input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 10). These functions will not be directly callable after loading.
# Model converted and saved as TensorFlow Lite: /content/drive/MyDrive/Colab Notebooks/Projects/Final(Undergraduate)/New/tflite/model.tflite
